# %%
# union all 1x2_odds files together and join to master data

# %%
# imports
import pandas as pd

# %%
# get 1x2 odds data for last few years
games_0 = pd.read_excel('data/2023_1x2_data.xlsx', header=0)
games_1 = pd.read_excel('data/2024_1x2_data.xlsx', header=0)
games_2 = pd.read_excel('data/2025_1x2_data.xlsx', header=0)

# union together
all_1x2_odds = pd.concat([games_0, games_1, games_2], ignore_index=True)

# reset index
all_1x2_odds.reset_index(drop=True, inplace=True)

# only keep key cols
key_cols = ['Game_Link'] + [x for x in all_1x2_odds.columns if x.startswith('Odds')]
all_1x2_odds = all_1x2_odds[key_cols]

# inspect
all_1x2_odds.info()
all_1x2_odds.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3381 entries, 0 to 3380
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Game_Link  3381 non-null   object
#  1   Odds_1     3256 non-null   float64
#  2   Odds_X     3256 non-null   float64
#  3   Odds_2     3256 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 105.8+ KB
#                                            Game_Link  Odds_1  Odds_X  Odds_2
# 0  https://www.flashscore.com/match/hockey/edmont...    2.45     4.0    2.45
# 1  https://www.flashscore.com/match/hockey/edmont...    2.35     4.0    2.55
# 2  https://www.flashscore.com/match/hockey/edmont...    2.00     4.0    3.10
# 3  https://www.flashscore.com/match/hockey/edmont...    2.30     4.0    2.55
# 4  https://www.flashscore.com/match/hockey/edmont...    2.15     4.0    2.80

# %%
# read in master games data
all_games = pd.read_excel(r'data/master_games_data.xlsx', header=0)

# inspect
all_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3381 entries, 0 to 3380
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Game_Link                 3381 non-null   object
#  1   Extra_Time                3381 non-null   object
#  2   Home_Team                 3381 non-null   object
#  3   Away_Team                 3381 non-null   object
#  4   Home_Score                3381 non-null   int64
#  5   Away_Score                3381 non-null   int64
#  6   P1_Home_Score             3381 non-null   int64
#  7   P1_Away_Score             3381 non-null   int64
#  8   P2_Home_Score             3381 non-null   int64
#  9   P2_Away_Score             3381 non-null   int64
#  10  P3_Home_Score             3381 non-null   int64
#  11  P3_Away_Score             3381 non-null   int64
#  12  P4_Home_Score             3381 non-null   int64
#  13  P4_Away_Score             3381 non-null   int64
#  14  P5_Home_Score             3381 non-null   int64
#  15  P5_Away_Score             3381 non-null   int64
#  16  Time                      3381 non-null   object
#  17  Month_int                 3381 non-null   int64
#  18  Date                      3381 non-null   datetime64[ns]
#  19  Season                    3381 non-null   int64
#  20  Total_Score               3381 non-null   int64
#  21  Game_ID                   3381 non-null   object
#  22  regular_time_score_home   3381 non-null   int64
#  23  regular_time_score_away   3381 non-null   int64
#  24  regular_time_score_total  3381 non-null   int64
#  25  Reg_Home_Win              3381 non-null   bool
#  26  Reg_Away_Win              3381 non-null   bool
#  27  Reg_Tie                   3381 non-null   bool
#  28  FT_Home_Win               3381 non-null   bool
#  29  FT_Away_Win               3381 non-null   bool
#  30  Day_of_Week               3381 non-null   object
#  31  Month                     3381 non-null   object
#  32  Week_of_Year              3381 non-null   int64
#  33  Home_Conf                 3336 non-null   object
#  34  Away_Conf                 3335 non-null   object
#  35  Home_Div                  3336 non-null   object
#  36  Away_Div                  3335 non-null   object
#  37  Conf_Matchup              3381 non-null   bool
#  38  Div_Matchup               3381 non-null   bool
#  39  Conf_Pair                 3290 non-null   object
#  40  Div_Pair                  3290 non-null   object
#  41  Team_Pair                 3381 non-null   object
#  42  Game_Start_Hour           3381 non-null   int64
# dtypes: bool(7), datetime64[ns](1), int64(20), object(15)
# memory usage: 974.1+ KB

# %%
# join the 2 dfs together
master_data = pd.merge(all_games, all_1x2_odds, how='left', on='Game_Link')

# inspect
master_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3381 entries, 0 to 3380
# Data columns (total 46 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Game_Link                 3381 non-null   object
#  1   Extra_Time                3381 non-null   object
#  2   Home_Team                 3381 non-null   object
#  3   Away_Team                 3381 non-null   object
#  4   Home_Score                3381 non-null   int64
#  5   Away_Score                3381 non-null   int64
#  6   P1_Home_Score             3381 non-null   int64
#  7   P1_Away_Score             3381 non-null   int64
#  8   P2_Home_Score             3381 non-null   int64
#  9   P2_Away_Score             3381 non-null   int64
#  10  P3_Home_Score             3381 non-null   int64
#  11  P3_Away_Score             3381 non-null   int64
#  12  P4_Home_Score             3381 non-null   int64
#  13  P4_Away_Score             3381 non-null   int64
#  14  P5_Home_Score             3381 non-null   int64
#  15  P5_Away_Score             3381 non-null   int64
#  16  Time                      3381 non-null   object
#  17  Month_int                 3381 non-null   int64
#  18  Date                      3381 non-null   datetime64[ns]
#  19  Season                    3381 non-null   int64
#  20  Total_Score               3381 non-null   int64
#  21  Game_ID                   3381 non-null   object
#  22  regular_time_score_home   3381 non-null   int64
#  23  regular_time_score_away   3381 non-null   int64
#  24  regular_time_score_total  3381 non-null   int64
#  25  Reg_Home_Win              3381 non-null   bool
#  26  Reg_Away_Win              3381 non-null   bool
#  27  Reg_Tie                   3381 non-null   bool
#  28  FT_Home_Win               3381 non-null   bool
#  29  FT_Away_Win               3381 non-null   bool
#  30  Day_of_Week               3381 non-null   object
#  31  Month                     3381 non-null   object
#  32  Week_of_Year              3381 non-null   int64
#  33  Home_Conf                 3336 non-null   object
#  34  Away_Conf                 3335 non-null   object
#  35  Home_Div                  3336 non-null   object
#  36  Away_Div                  3335 non-null   object
#  37  Conf_Matchup              3381 non-null   bool
#  38  Div_Matchup               3381 non-null   bool
#  39  Conf_Pair                 3290 non-null   object
#  40  Div_Pair                  3290 non-null   object
#  41  Team_Pair                 3381 non-null   object
#  42  Game_Start_Hour           3381 non-null   int64
#  43  Odds_1                    3256 non-null   float64
#  44  Odds_X                    3256 non-null   float64
#  45  Odds_2                    3256 non-null   float64
# dtypes: bool(7), datetime64[ns](1), float64(3), int64(20), object(15)
# memory usage: 1.0+ MB

# %%
# TODO - perform EDA on records that resulted in a regular time tie and see if there's any patterns or trends in this subset that could be indicative of predictive features
master_data[master_data['Reg_Tie'] == True].describe()
# Out:
#        Home_Score  Away_Score  P1_Home_Score  P1_Away_Score  P2_Home_Score  \
# count  714.000000  714.000000     714.000000     714.000000     714.000000
# mean     3.137255    3.075630       0.809524       0.810924       0.924370
# min      0.000000    0.000000       0.000000       0.000000       0.000000
# 25%      2.000000    2.000000       0.000000       0.000000       0.000000
# 50%      3.000000    3.000000       1.000000       1.000000       1.000000
# 75%      4.000000    4.000000       1.000000       1.000000       1.000000
# max      8.000000    7.000000       5.000000       4.000000       4.000000
# std      1.246903    1.277662       0.823988       0.828553       0.881408
#
#        P2_Away_Score  P3_Home_Score  P3_Away_Score  P4_Home_Score  \
# count     714.000000     714.000000     714.000000     714.000000
# mean        0.911765       0.872549       0.883754       0.385154
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.000000       1.000000       1.000000       0.000000
# 75%         1.000000       1.000000       1.000000       1.000000
# max         4.000000       5.000000       5.000000       1.000000
# std         0.873035       0.866553       0.845209       0.486973
#
#        P4_Away_Score  ...       Season  Total_Score  regular_time_score_home  \
# count     714.000000  ...   714.000000   714.000000               714.000000
# mean        0.334734  ...  2023.694678     6.212885                 2.606443
# min         0.000000  ...  2023.000000     1.000000                 0.000000
# 25%         0.000000  ...  2023.000000     5.000000                 2.000000
# 50%         0.000000  ...  2024.000000     7.000000                 3.000000
# 75%         1.000000  ...  2024.000000     7.000000                 3.000000
# max         1.000000  ...  2025.000000    15.000000                 7.000000
# std         0.472228  ...     0.689980     2.318788                 1.159394
#
#       regular_time_score_away  regular_time_score_total  Week_of_Year  \
# count              714.000000                714.000000    714.000000
# mean                 2.606443                  5.212885     28.043417
# min                  0.000000                  0.000000      1.000000
# 25%                  2.000000                  4.000000     10.000000
# 50%                  3.000000                  6.000000     39.000000
# 75%                  3.000000                  6.000000     45.000000
# max                  7.000000                 14.000000     52.000000
# std                  1.159394                  2.318788     18.216543
#
#        Game_Start_Hour      Odds_1      Odds_X      Odds_2
# count       714.000000  686.000000  686.000000  686.000000
# mean         19.222689    2.322996    4.292580    2.900809
# min           8.000000    1.290000    3.800000    1.380000
# 25%          19.000000    1.840000    4.100000    2.250000
# 50%          19.000000    2.175000    4.225000    2.700000
# 75%          21.000000    2.625000    4.425000    3.300000
# max          22.000000    6.125000    6.000000    8.500000
# std           2.246890    0.666261    0.292265    0.920375
#
# [8 rows x 24 columns]

# %%
# function that takes the df, sorts it by the target grain, then performs the groupby
def grain_sort_cumsum_props(home_vs_away: str, df: pd.DataFrame) -> pd.DataFrame:
    # add home or away team to sort grain
    home_plus_year = [home_vs_away, 'Season']
    
    # combine to create final sort grain
    # sort_grain = home_plus_year + ['Date', 'Game_ID']
    sort_grain = home_plus_year + ['Date']

    # sort
    df = df.sort_values(by=sort_grain)

    # hard code cumsum cols
    cum_cols = ["Reg_Home_Win", "Reg_Away_Win", "Reg_Tie", 'P1_Home_Score', 'P1_Away_Score', 
                'P2_Home_Score', 'P2_Away_Score', 'P3_Home_Score', 'P3_Away_Score',
                'regular_time_score_home', 'regular_time_score_away']
    
    # add count of games for home or away
    df[f'cum_{home_vs_away}_Games'] = df.groupby(home_plus_year).cumcount() + 1

    # compute cumsum for each group
    df[[f"cum_{col}" for col in cum_cols]] = df.groupby(home_plus_year)[cum_cols].cumsum()

    # calc prop home reg win
    df['prop_Reg_Home_Win'] = df['cum_Reg_Home_Win'] / df[f'cum_{home_vs_away}_Games']
    df['prop_Reg_Away_Win'] = df['cum_Reg_Away_Win'] / df[f'cum_{home_vs_away}_Games']
    df['prop_Reg_Tie'] = df['cum_Reg_Tie'] / df[f'cum_{home_vs_away}_Games']

    # calc props for what % of goals scored in each period
    df['prop_P1_Home_Score'] = df['cum_P1_Home_Score'] / df['cum_regular_time_score_home']
    df['prop_P2_Home_Score'] = df['cum_P2_Home_Score'] / df['cum_regular_time_score_home']
    df['prop_P3_Home_Score'] = df['cum_P3_Home_Score'] / df['cum_regular_time_score_home']

    df['prop_P1_Away_Score'] = df['cum_P1_Away_Score'] / df['cum_regular_time_score_away']
    df['prop_P2_Away_Score'] = df['cum_P2_Away_Score'] / df['cum_regular_time_score_away']
    df['prop_P3_Away_Score'] = df['cum_P3_Away_Score'] / df['cum_regular_time_score_away']

    # calc goal diffs at the period level
    df['prop_P1_Home_Goal_Diff'] = df['cum_P1_Home_Score'] / df['cum_P1_Away_Score']
    df['prop_P2_Home_Goal_Diff'] = df['cum_P2_Home_Score'] / df['cum_P2_Away_Score']
    df['prop_P3_Home_Goal_Diff'] = df['cum_P3_Home_Score'] / df['cum_P3_Away_Score']

    df['prop_P1_Away_Goal_Diff'] = df['cum_P1_Away_Score'] / df['cum_P1_Home_Score']
    df['prop_P2_Away_Goal_Diff'] = df['cum_P2_Away_Score'] / df['cum_P2_Home_Score']
    df['prop_P3_Away_Goal_Diff'] = df['cum_P3_Away_Score'] / df['cum_P3_Home_Score']

    # calc props for goals scored / allowed
    df['prop_reg_home_goal_diff'] = df['cum_regular_time_score_home'] / (df['cum_regular_time_score_home'] + df['cum_regular_time_score_away'])
    df['prop_reg_away_goal_diff'] = 1 - df['prop_reg_home_goal_diff']

    # calc avg goals per game
    df['avg_reg_home_goals_per_game'] = df['cum_regular_time_score_home'] / df[f'cum_{home_vs_away}_Games']
    df['avg_reg_away_goals_per_game'] = df['cum_regular_time_score_away'] / df[f'cum_{home_vs_away}_Games']

    # isolate cum, prop, and avg cols
    sel_cum_cols = [x for x in df.columns if x.startswith('prop_') or x.startswith('avg_')]

    # trim to final cols
    final_cols = sort_grain + sel_cum_cols
    df = df[final_cols]

    # shift feature cols down that are not in sort_grain
    df[sel_cum_cols] = df.groupby(home_plus_year)[sel_cum_cols].shift(1)

    # rename the sel_cum_cols to indicate home vs away
    if home_vs_away == 'Home_Team':
        home_vs_away = 'Home'
    else:
        home_vs_away = 'Away'
    
    rename_dict = {col: f"{col}_{home_vs_away}" for col in sel_cum_cols}
    df = df.rename(columns=rename_dict)

    return df

# test func
all_home_games = grain_sort_cumsum_props('Home_Team', master_data)
all_home_games.info()
all_home_games.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3381 entries, 1496 to 3095
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Home_Team                         3381 non-null   object
#  1   Season                            3381 non-null   int64
#  2   Date                              3381 non-null   datetime64[ns]
#  3   prop_Reg_Home_Win_Home            3285 non-null   float64
#  4   prop_Reg_Away_Win_Home            3285 non-null   float64
#  5   prop_Reg_Tie_Home                 3285 non-null   float64
#  6   prop_P1_Home_Score_Home           3284 non-null   float64
#  7   prop_P2_Home_Score_Home           3284 non-null   float64
#  8   prop_P3_Home_Score_Home           3284 non-null   float64
#  9   prop_P1_Away_Score_Home           3272 non-null   float64
#  10  prop_P2_Away_Score_Home           3272 non-null   float64
#  11  prop_P3_Away_Score_Home           3272 non-null   float64
#  12  prop_P1_Home_Goal_Diff_Home       3269 non-null   float64
#  13  prop_P2_Home_Goal_Diff_Home       3268 non-null   float64
#  14  prop_P3_Home_Goal_Diff_Home       3270 non-null   float64
#  15  prop_P1_Away_Goal_Diff_Home       3269 non-null   float64
#  16  prop_P2_Away_Goal_Diff_Home       3268 non-null   float64
#  17  prop_P3_Away_Goal_Diff_Home       3270 non-null   float64
#  18  prop_reg_home_goal_diff_Home      3285 non-null   float64
#  19  prop_reg_away_goal_diff_Home      3285 non-null   float64
#  20  avg_reg_home_goals_per_game_Home  3285 non-null   float64
#  21  avg_reg_away_goals_per_game_Home  3285 non-null   float64
# dtypes: datetime64[ns](1), float64(19), int64(1), object(1)
# memory usage: 607.5+ KB
#           Home_Team  Season       Date  prop_Reg_Home_Win_Home  \
# 1496  Anaheim Ducks    2023 2023-09-24                     NaN
# 1471  Anaheim Ducks    2023 2023-09-27                0.000000
# 1457  Anaheim Ducks    2023 2023-09-29                0.500000
# 1413  Anaheim Ducks    2023 2023-10-05                0.333333
# 1366  Anaheim Ducks    2023 2023-10-15                0.250000
#
#       prop_Reg_Away_Win_Home  prop_Reg_Tie_Home  prop_P1_Home_Score_Home  \
# 1496                     NaN                NaN                      NaN
# 1471                0.000000           1.000000                 0.500000
# 1457                0.000000           0.500000                 0.500000
# 1413                0.333333           0.333333                 0.444444
# 1366                0.500000           0.250000                 0.363636
#
#       prop_P2_Home_Score_Home  prop_P3_Home_Score_Home  \
# 1496                      NaN                      NaN
# 1471                 0.000000                 0.500000
# 1457                 0.166667                 0.333333
# 1413                 0.222222                 0.333333
# 1366                 0.181818                 0.454545
#
#       prop_P1_Away_Score_Home  ...  prop_P1_Home_Goal_Diff_Home  \
# 1496                      NaN  ...                          NaN
# 1471                 0.000000  ...                          inf
# 1457                 0.250000  ...                          3.0
# 1413                 0.500000  ...                          1.0
# 1366                 0.333333  ...                          1.0
#
#       prop_P2_Home_Goal_Diff_Home  prop_P3_Home_Goal_Diff_Home  \
# 1496                          NaN                          NaN
# 1471                          0.0                         1.00
# 1457                          1.0                         1.00
# 1413                          1.0                         1.50
# 1366                          0.5                         1.25
#
#       prop_P1_Away_Goal_Diff_Home  prop_P2_Away_Goal_Diff_Home  \
# 1496                          NaN                          NaN
# 1471                     0.000000                          inf
# 1457                     0.333333                          1.0
# 1413                     1.000000                          1.0
# 1366                     1.000000                          2.0
#
#       prop_P3_Away_Goal_Diff_Home  prop_reg_home_goal_diff_Home  \
# 1496                          NaN                           NaN
# 1471                     1.000000                      0.500000
# 1457                     1.000000                      0.600000
# 1413                     0.666667                      0.529412
# 1366                     0.800000                      0.478261
#
#       prop_reg_away_goal_diff_Home  avg_reg_home_goals_per_game_Home  \
# 1496                           NaN                               NaN
# 1471                      0.500000                              2.00
# 1457                      0.400000                              3.00
# 1413                      0.470588                              3.00
# 1366                      0.521739                              2.75
#
#       avg_reg_away_goals_per_game_Home
# 1496                               NaN
# 1471                          2.000000
# 1457                          2.000000
# 1413                          2.666667
# 1366                          3.000000
#
# [5 rows x 22 columns]

# %%
# repeat for away teams
all_away_games = grain_sort_cumsum_props('Away_Team', master_data)
all_away_games.info()
all_away_games.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3381 entries, 1480 to 3014
# Data columns (total 22 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Away_Team                         3381 non-null   object
#  1   Season                            3381 non-null   int64
#  2   Date                              3381 non-null   datetime64[ns]
#  3   prop_Reg_Home_Win_Away            3285 non-null   float64
#  4   prop_Reg_Away_Win_Away            3285 non-null   float64
#  5   prop_Reg_Tie_Away                 3285 non-null   float64
#  6   prop_P1_Home_Score_Away           3283 non-null   float64
#  7   prop_P2_Home_Score_Away           3283 non-null   float64
#  8   prop_P3_Home_Score_Away           3283 non-null   float64
#  9   prop_P1_Away_Score_Away           3275 non-null   float64
#  10  prop_P2_Away_Score_Away           3275 non-null   float64
#  11  prop_P3_Away_Score_Away           3275 non-null   float64
#  12  prop_P1_Home_Goal_Diff_Away       3270 non-null   float64
#  13  prop_P2_Home_Goal_Diff_Away       3266 non-null   float64
#  14  prop_P3_Home_Goal_Diff_Away       3267 non-null   float64
#  15  prop_P1_Away_Goal_Diff_Away       3270 non-null   float64
#  16  prop_P2_Away_Goal_Diff_Away       3266 non-null   float64
#  17  prop_P3_Away_Goal_Diff_Away       3267 non-null   float64
#  18  prop_reg_home_goal_diff_Away      3285 non-null   float64
#  19  prop_reg_away_goal_diff_Away      3285 non-null   float64
#  20  avg_reg_home_goals_per_game_Away  3285 non-null   float64
#  21  avg_reg_away_goals_per_game_Away  3285 non-null   float64
# dtypes: datetime64[ns](1), float64(19), int64(1), object(1)
# memory usage: 607.5+ KB
#           Away_Team  Season       Date  prop_Reg_Home_Win_Away  \
# 1480  Anaheim Ducks    2023 2023-09-26                     NaN
# 1445  Anaheim Ducks    2023 2023-10-01                0.000000
# 1430  Anaheim Ducks    2023 2023-10-03                0.000000
# 1404  Anaheim Ducks    2023 2023-10-07                0.333333
# 1371  Anaheim Ducks    2023 2023-10-14                0.500000
#
#       prop_Reg_Away_Win_Away  prop_Reg_Tie_Away  prop_P1_Home_Score_Away  \
# 1480                     NaN                NaN                      NaN
# 1445                1.000000                0.0                 0.000000
# 1430                1.000000                0.0                 0.500000
# 1404                0.666667                0.0                 0.600000
# 1371                0.500000                0.0                 0.411765
#
#       prop_P2_Home_Score_Away  prop_P3_Home_Score_Away  \
# 1480                      NaN                      NaN
# 1445                 0.500000                 0.500000
# 1430                 0.333333                 0.166667
# 1404                 0.200000                 0.200000
# 1371                 0.352941                 0.235294
#
#       prop_P1_Away_Score_Away  ...  prop_P1_Home_Goal_Diff_Away  \
# 1480                      NaN  ...                          NaN
# 1445                 0.750000  ...                          0.0
# 1430                 0.555556  ...                          0.6
# 1404                 0.500000  ...                          1.2
# 1371                 0.454545  ...                          1.4
#
#       prop_P2_Home_Goal_Diff_Away  prop_P3_Home_Goal_Diff_Away  \
# 1480                          NaN                          NaN
# 1445                          inf                     1.000000
# 1430                          2.0                     0.333333
# 1404                          1.0                     0.666667
# 1371                          3.0                     1.000000
#
#       prop_P1_Away_Goal_Diff_Away  prop_P2_Away_Goal_Diff_Away  \
# 1480                          NaN                          NaN
# 1445                          inf                     0.000000
# 1430                     1.666667                     0.500000
# 1404                     0.833333                     1.000000
# 1371                     0.714286                     0.333333
#
#       prop_P3_Away_Goal_Diff_Away  prop_reg_home_goal_diff_Away  \
# 1480                          NaN                           NaN
# 1445                          1.0                      0.333333
# 1430                          3.0                      0.400000
# 1404                          1.5                      0.500000
# 1371                          1.0                      0.607143
#
#       prop_reg_away_goal_diff_Away  avg_reg_home_goals_per_game_Away  \
# 1480                           NaN                               NaN
# 1445                      0.666667                          2.000000
# 1430                      0.600000                          3.000000
# 1404                      0.500000                          3.333333
# 1371                      0.392857                          4.250000
#
#       avg_reg_away_goals_per_game_Away
# 1480                               NaN
# 1445                          4.000000
# 1430                          4.500000
# 1404                          3.333333
# 1371                          2.750000
#
# [5 rows x 22 columns]

# %%
# sort by Home then away then date and get cum avgs
def h2h_grain_sort_cumsum_props(df: pd.DataFrame) -> pd.DataFrame:
    # add home or away team to sort grain
    home_plus_year = ['Home_Team', 'Away_Team', 'Season']
    
    # combine to create final sort grain
    sort_grain = home_plus_year + ['Date']

    # sort
    df = df.sort_values(by=sort_grain)

    # hard code cumsum cols
    cum_cols = ["Reg_Home_Win", "Reg_Away_Win", "Reg_Tie", 'P1_Home_Score', 'P1_Away_Score', 
                'P2_Home_Score', 'P2_Away_Score', 'P3_Home_Score', 'P3_Away_Score',
                'regular_time_score_home', 'regular_time_score_away']
    
    # add count of games for home or away
    df[f'cum_Games'] = df.groupby(home_plus_year).cumcount() + 1

    # compute cumsum for each group
    df[[f"cum_{col}" for col in cum_cols]] = df.groupby(home_plus_year)[cum_cols].cumsum()

    # calc prop home reg win
    df['prop_Reg_Home_Win'] = df['cum_Reg_Home_Win'] / df[f'cum_Games']
    df['prop_Reg_Away_Win'] = df['cum_Reg_Away_Win'] / df[f'cum_Games']
    df['prop_Reg_Tie'] = df['cum_Reg_Tie'] / df[f'cum_Games']

    # calc props for what % of goals scored in each period
    df['prop_P1_Home_Score'] = df['cum_P1_Home_Score'] / df['cum_regular_time_score_home']
    df['prop_P2_Home_Score'] = df['cum_P2_Home_Score'] / df['cum_regular_time_score_home']
    df['prop_P3_Home_Score'] = df['cum_P3_Home_Score'] / df['cum_regular_time_score_home']

    df['prop_P1_Away_Score'] = df['cum_P1_Away_Score'] / df['cum_regular_time_score_away']
    df['prop_P2_Away_Score'] = df['cum_P2_Away_Score'] / df['cum_regular_time_score_away']
    df['prop_P3_Away_Score'] = df['cum_P3_Away_Score'] / df['cum_regular_time_score_away']

    # calc goal diffs at the period level
    df['prop_P1_Home_Goal_Diff'] = df['cum_P1_Home_Score'] / df['cum_P1_Away_Score']
    df['prop_P2_Home_Goal_Diff'] = df['cum_P2_Home_Score'] / df['cum_P2_Away_Score']
    df['prop_P3_Home_Goal_Diff'] = df['cum_P3_Home_Score'] / df['cum_P3_Away_Score']

    df['prop_P1_Away_Goal_Diff'] = df['cum_P1_Away_Score'] / df['cum_P1_Home_Score']
    df['prop_P2_Away_Goal_Diff'] = df['cum_P2_Away_Score'] / df['cum_P2_Home_Score']
    df['prop_P3_Away_Goal_Diff'] = df['cum_P3_Away_Score'] / df['cum_P3_Home_Score']

    # calc props for goals scored / allowed
    df['prop_reg_home_goal_diff'] = df['cum_regular_time_score_home'] / (df['cum_regular_time_score_home'] + df['cum_regular_time_score_away'])
    df['prop_reg_away_goal_diff'] = 1 - df['prop_reg_home_goal_diff']

    # calc avg goals per game
    df['avg_reg_home_goals_per_game'] = df['cum_regular_time_score_home'] / df[f'cum_Games']
    df['avg_reg_away_goals_per_game'] = df['cum_regular_time_score_away'] / df[f'cum_Games']

    # isolate cum, prop, and avg cols
    sel_cum_cols = [x for x in df.columns if x.startswith('prop_') or x.startswith('avg_')]

    # trim to final cols
    final_cols = sort_grain + sel_cum_cols
    df = df[final_cols]

    # shift feature cols down that are not in sort_grain
    df[sel_cum_cols] = df.groupby(home_plus_year)[sel_cum_cols].shift(1)
    
    rename_dict = {col: f"{col}_H2H" for col in sel_cum_cols}
    df = df.rename(columns=rename_dict)

    return df

# test func
h2h_cum_df = h2h_grain_sort_cumsum_props(master_data)
h2h_cum_df.info()
h2h_cum_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3381 entries, 1413 to 1777
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Home_Team                        3381 non-null   object
#  1   Away_Team                        3381 non-null   object
#  2   Season                           3381 non-null   int64
#  3   Date                             3381 non-null   datetime64[ns]
#  4   prop_Reg_Home_Win_H2H            1074 non-null   float64
#  5   prop_Reg_Away_Win_H2H            1074 non-null   float64
#  6   prop_Reg_Tie_H2H                 1074 non-null   float64
#  7   prop_P1_Home_Score_H2H           1049 non-null   float64
#  8   prop_P2_Home_Score_H2H           1049 non-null   float64
#  9   prop_P3_Home_Score_H2H           1049 non-null   float64
#  10  prop_P1_Away_Score_H2H           1026 non-null   float64
#  11  prop_P2_Away_Score_H2H           1026 non-null   float64
#  12  prop_P3_Away_Score_H2H           1026 non-null   float64
#  13  prop_P1_Home_Goal_Diff_H2H       943 non-null    float64
#  14  prop_P2_Home_Goal_Diff_H2H       976 non-null    float64
#  15  prop_P3_Home_Goal_Diff_H2H       976 non-null    float64
#  16  prop_P1_Away_Goal_Diff_H2H       943 non-null    float64
#  17  prop_P2_Away_Goal_Diff_H2H       976 non-null    float64
#  18  prop_P3_Away_Goal_Diff_H2H       976 non-null    float64
#  19  prop_reg_home_goal_diff_H2H      1072 non-null   float64
#  20  prop_reg_away_goal_diff_H2H      1072 non-null   float64
#  21  avg_reg_home_goals_per_game_H2H  1074 non-null   float64
#  22  avg_reg_away_goals_per_game_H2H  1074 non-null   float64
# dtypes: datetime64[ns](1), float64(19), int64(1), object(2)
# memory usage: 633.9+ KB
#           Home_Team        Away_Team  Season       Date  \
# 1413  Anaheim Ducks  Arizona Coyotes    2023 2023-10-05
# 1256  Anaheim Ducks  Arizona Coyotes    2023 2023-11-01
# 846   Anaheim Ducks  Arizona Coyotes    2023 2023-12-29
# 1319  Anaheim Ducks    Boston Bruins    2023 2023-10-22
# 1768  Anaheim Ducks    Boston Bruins    2024 2025-03-26
#
#       prop_Reg_Home_Win_H2H  prop_Reg_Away_Win_H2H  prop_Reg_Tie_H2H  \
# 1413                    NaN                    NaN               NaN
# 1256                    0.0                    1.0               0.0
# 846                     0.0                    0.5               0.5
# 1319                    NaN                    NaN               NaN
# 1768                    NaN                    NaN               NaN
#
#       prop_P1_Home_Score_H2H  prop_P2_Home_Score_H2H  prop_P3_Home_Score_H2H  \
# 1413                     NaN                     NaN                     NaN
# 1256                     0.0                     0.0                     1.0
# 846                      0.4                     0.0                     0.6
# 1319                     NaN                     NaN                     NaN
# 1768                     NaN                     NaN                     NaN
#
#       ...  prop_P1_Home_Goal_Diff_H2H  prop_P2_Home_Goal_Diff_H2H  \
# 1413  ...                         NaN                         NaN
# 1256  ...                         NaN                         0.0
# 846   ...                         1.0                         0.0
# 1319  ...                         NaN                         NaN
# 1768  ...                         NaN                         NaN
#
#       prop_P3_Home_Goal_Diff_H2H  prop_P1_Away_Goal_Diff_H2H  \
# 1413                         NaN                         NaN
# 1256                         1.0                         NaN
# 846                          1.5                         1.0
# 1319                         NaN                         NaN
# 1768                         NaN                         NaN
#
#       prop_P2_Away_Goal_Diff_H2H  prop_P3_Away_Goal_Diff_H2H  \
# 1413                         NaN                         NaN
# 1256                         inf                    1.000000
# 846                          inf                    0.666667
# 1319                         NaN                         NaN
# 1768                         NaN                         NaN
#
#       prop_reg_home_goal_diff_H2H  prop_reg_away_goal_diff_H2H  \
# 1413                          NaN                          NaN
# 1256                     0.333333                     0.666667
# 846                      0.416667                     0.583333
# 1319                          NaN                          NaN
# 1768                          NaN                          NaN
#
#       avg_reg_home_goals_per_game_H2H  avg_reg_away_goals_per_game_H2H
# 1413                              NaN                              NaN
# 1256                              2.0                              4.0
# 846                               2.5                              3.5
# 1319                              NaN                              NaN
# 1768                              NaN                              NaN
#
# [5 rows x 23 columns]

# %%
# get key cols from master data
base_cols = ['Date', 'Season', 'Game_ID', 'Home_Team', 'Away_Team',
    'Odds_1', 'Odds_X', 'Odds_2', 'Reg_Home_Win', 'Reg_Away_Win', 'Reg_Tie',
    'Month', 'Day_of_Week', 'Conf_Matchup', 'Div_Matchup', 'Conf_Pair', 'Div_Pair',
    'Team_Pair'
    ]

modeling_data_base = master_data[base_cols]

# ensure data sorted correctly
modeling_data = modeling_data_base.sort_values(by=['Home_Team', 'Season', 'Date'])

# join home and away dfs to modeling data
modeling_data = modeling_data.merge(all_home_games, how='left', on=['Home_Team', 'Season', 'Date'])
modeling_data = modeling_data.merge(all_away_games, how='left', on=['Away_Team', 'Season', 'Date'])

# join in h2h data
modeling_data = modeling_data.merge(h2h_cum_df, how='left', on=['Home_Team', 'Away_Team', 'Season', 'Date'])

# inspect
modeling_data.info()
modeling_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3429 entries, 0 to 3428
# Data columns (total 75 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Date                              3429 non-null   datetime64[ns]
#  1   Season                            3429 non-null   int64
#  2   Game_ID                           3429 non-null   object
#  3   Home_Team                         3429 non-null   object
#  4   Away_Team                         3429 non-null   object
#  5   Odds_1                            3256 non-null   float64
#  6   Odds_X                            3256 non-null   float64
#  7   Odds_2                            3256 non-null   float64
#  8   Reg_Home_Win                      3429 non-null   bool
#  9   Reg_Away_Win                      3429 non-null   bool
#  10  Reg_Tie                           3429 non-null   bool
#  11  Month                             3429 non-null   object
#  12  Day_of_Week                       3429 non-null   object
#  13  Conf_Matchup                      3429 non-null   bool
#  14  Div_Matchup                       3429 non-null   bool
#  15  Conf_Pair                         3334 non-null   object
#  16  Div_Pair                          3334 non-null   object
#  17  Team_Pair                         3429 non-null   object
#  18  prop_Reg_Home_Win_Home            3308 non-null   float64
#  19  prop_Reg_Away_Win_Home            3308 non-null   float64
#  20  prop_Reg_Tie_Home                 3308 non-null   float64
#  21  prop_P1_Home_Score_Home           3307 non-null   float64
#  22  prop_P2_Home_Score_Home           3307 non-null   float64
#  23  prop_P3_Home_Score_Home           3307 non-null   float64
#  24  prop_P1_Away_Score_Home           3295 non-null   float64
#  25  prop_P2_Away_Score_Home           3295 non-null   float64
#  26  prop_P3_Away_Score_Home           3295 non-null   float64
#  27  prop_P1_Home_Goal_Diff_Home       3292 non-null   float64
#  28  prop_P2_Home_Goal_Diff_Home       3291 non-null   float64
#  29  prop_P3_Home_Goal_Diff_Home       3293 non-null   float64
#  30  prop_P1_Away_Goal_Diff_Home       3292 non-null   float64
#  31  prop_P2_Away_Goal_Diff_Home       3291 non-null   float64
#  32  prop_P3_Away_Goal_Diff_Home       3293 non-null   float64
#  33  prop_reg_home_goal_diff_Home      3308 non-null   float64
#  34  prop_reg_away_goal_diff_Home      3308 non-null   float64
#  35  avg_reg_home_goals_per_game_Home  3308 non-null   float64
#  36  avg_reg_away_goals_per_game_Home  3308 non-null   float64
#  37  prop_Reg_Home_Win_Away            3309 non-null   float64
#  38  prop_Reg_Away_Win_Away            3309 non-null   float64
#  39  prop_Reg_Tie_Away                 3309 non-null   float64
#  40  prop_P1_Home_Score_Away           3307 non-null   float64
#  41  prop_P2_Home_Score_Away           3307 non-null   float64
#  42  prop_P3_Home_Score_Away           3307 non-null   float64
#  43  prop_P1_Away_Score_Away           3298 non-null   float64
#  44  prop_P2_Away_Score_Away           3298 non-null   float64
#  45  prop_P3_Away_Score_Away           3298 non-null   float64
#  46  prop_P1_Home_Goal_Diff_Away       3294 non-null   float64
#  47  prop_P2_Home_Goal_Diff_Away       3290 non-null   float64
#  48  prop_P3_Home_Goal_Diff_Away       3291 non-null   float64
#  49  prop_P1_Away_Goal_Diff_Away       3294 non-null   float64
#  50  prop_P2_Away_Goal_Diff_Away       3290 non-null   float64
#  51  prop_P3_Away_Goal_Diff_Away       3291 non-null   float64
#  52  prop_reg_home_goal_diff_Away      3309 non-null   float64
#  53  prop_reg_away_goal_diff_Away      3309 non-null   float64
#  54  avg_reg_home_goals_per_game_Away  3309 non-null   float64
#  55  avg_reg_away_goals_per_game_Away  3309 non-null   float64
#  56  prop_Reg_Home_Win_H2H             1095 non-null   float64
#  57  prop_Reg_Away_Win_H2H             1095 non-null   float64
#  58  prop_Reg_Tie_H2H                  1095 non-null   float64
#  59  prop_P1_Home_Score_H2H            1070 non-null   float64
#  60  prop_P2_Home_Score_H2H            1070 non-null   float64
#  61  prop_P3_Home_Score_H2H            1070 non-null   float64
#  62  prop_P1_Away_Score_H2H            1047 non-null   float64
#  63  prop_P2_Away_Score_H2H            1047 non-null   float64
#  64  prop_P3_Away_Score_H2H            1047 non-null   float64
#  65  prop_P1_Home_Goal_Diff_H2H        964 non-null    float64
#  66  prop_P2_Home_Goal_Diff_H2H        997 non-null    float64
#  67  prop_P3_Home_Goal_Diff_H2H        997 non-null    float64
#  68  prop_P1_Away_Goal_Diff_H2H        964 non-null    float64
#  69  prop_P2_Away_Goal_Diff_H2H        997 non-null    float64
#  70  prop_P3_Away_Goal_Diff_H2H        997 non-null    float64
#  71  prop_reg_home_goal_diff_H2H       1093 non-null   float64
#  72  prop_reg_away_goal_diff_H2H       1093 non-null   float64
#  73  avg_reg_home_goals_per_game_H2H   1095 non-null   float64
#  74  avg_reg_away_goals_per_game_H2H   1095 non-null   float64
# dtypes: bool(5), datetime64[ns](1), float64(60), int64(1), object(8)
# memory usage: 1.8+ MB
#         Date  Season                                            Game_ID  \
# 0 2023-09-24    2023  2023-09-24-20:00|Anaheim Ducks vs Los Angeles ...
# 1 2023-09-27    2023  2023-09-27-22:00|Anaheim Ducks vs San Jose Sharks
# 2 2023-09-29    2023  2023-09-29-22:00|Anaheim Ducks vs Los Angeles ...
# 3 2023-10-05    2023  2023-10-05-22:00|Anaheim Ducks vs Arizona Coyotes
# 4 2023-10-15    2023  2023-10-15-20:30|Anaheim Ducks vs Carolina Hur...
#
#        Home_Team            Away_Team  Odds_1  Odds_X  Odds_2  Reg_Home_Win  \
# 0  Anaheim Ducks    Los Angeles Kings     NaN     NaN     NaN         False
# 1  Anaheim Ducks      San Jose Sharks     NaN     NaN     NaN          True
# 2  Anaheim Ducks    Los Angeles Kings     NaN     NaN     NaN         False
# 3  Anaheim Ducks      Arizona Coyotes     NaN     NaN     NaN         False
# 4  Anaheim Ducks  Carolina Hurricanes    4.75    4.75    1.56          True
#
#    Reg_Away_Win  ...  prop_P1_Home_Goal_Diff_H2H prop_P2_Home_Goal_Diff_H2H  \
# 0         False  ...                         NaN                        NaN
# 1         False  ...                         NaN                        NaN
# 2          True  ...                         inf                        0.0
# 3          True  ...                         NaN                        NaN
# 4         False  ...                         NaN                        NaN
#
#   prop_P3_Home_Goal_Diff_H2H  prop_P1_Away_Goal_Diff_H2H  \
# 0                        NaN                         NaN
# 1                        NaN                         NaN
# 2                        1.0                         0.0
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    prop_P2_Away_Goal_Diff_H2H prop_P3_Away_Goal_Diff_H2H  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         inf                        1.0
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#   prop_reg_home_goal_diff_H2H prop_reg_away_goal_diff_H2H  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         0.5                         0.5
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    avg_reg_home_goals_per_game_H2H  avg_reg_away_goals_per_game_H2H
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              2.0                              2.0
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
# [5 rows x 75 columns]

# %%
# write final modeling data to excel
modeling_data.to_excel(r'data/modeling_data.xlsx', index=False)

# %%
# Note that most NHL teams play 3-5 games per week
